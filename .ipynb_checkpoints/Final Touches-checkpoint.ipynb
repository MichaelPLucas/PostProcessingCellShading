# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from skimage import filters
from skimage import feature
from skimage import color
from scipy import ndimage
import numpy as np

start = plt.imread("intermediary.png")
pixels = len(start) * len(start[0])

blurred = filters.gaussian(start, pixels / 400000.0)

gray = color.rgb2grey(blurred)

dx = ndimage.sobel(gray, 0)  # horizontal derivative
dy = ndimage.sobel(gray, 1)  # vertical derivative
mag = np.hypot(dx, dy)  # magnitude
mag *= 255.0 / np.max(mag)  # normalize (Q&D)
mag = ndimage.filters.convolve(mag, [[3/18.0, 1/18.0, 3/18.0], [1/18.0, 2/18.0, 1/18.0], [3/18.0, 1/18.0, 3/18.0]])

end = start
for i in range(len(end)):
    for j in range(len(end[0])):
        if (mag[i][j] > 38):
            if (type(end[i][j]) is np.array):
                end[i][j] = [0, 0, 0]
            else:
                end[i][j] = 0

end = filters.gaussian(end, pixels / 600000.0)

if (type(end[0][0]) is not np.ndarray):
    print(type(end[0][0]))
    end = [[[x, x, x] for x in row] for row in end]

plt.imshow(end)
plt.show()
# Out:
# /opt/anaconda/lib/python3.6/site-packages/skimage/filters/_gaussian.py:94: RuntimeWarning: Images with dimensions (M, N, 3) are interpreted as 2D+RGB by default. Use `multichannel=False` to interpret as 3D image with last dimension of length 3.
#   warn(RuntimeWarning(msg))
